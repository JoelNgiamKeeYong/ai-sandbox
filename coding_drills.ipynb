# %% [markdown]
# # **🧑‍💻 Common Shortcuts and CLI Commands**

# %% [markdown]
# ---
# ---
# # **🖖 VS Code Shortcuts**

# %% [markdown]
# ---
# ## └─ Open new working folder
#
# - Open new VS Code window
# - Open new folder
#
# ```
# CTRL + SHIFT + N
# CTRL K
# CTRL O
# ```

# %% [markdown]
# ---
# ---
# # **⏩ CLI Shortcuts**

# %% [markdown]
# ---
# ## └─ Create new GitHub repo from GitHub CLI
#
# - To create a new repository on the command line using the GitHub CLI
#
# ```sh
# gh repo create aiap-foundation-hdb-resale --public --source=. --remote=origin --push
# ```

# %% [markdown]
# ---
# ---
# # **🌈 Google Chrome Shortcuts**

# %% [markdown]
# ---
# ## └─ Re-open closed tab
#
# ```
# CTRL + SHIFT + T
# ```

# %% [markdown]
# ---
# ---
# ---
